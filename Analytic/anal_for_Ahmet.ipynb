# %%
import pandas as pd
import csv
from ast import literal_eval

# %%
# pd.read_csv("year_2021.csv")[["name", "description", "key_skills"]].to_csv("year_2021_cut.csv")
# pd.read_csv("year_2020.csv")[["name", "description", "key_skills"]].to_csv("year_2020_cut.csv")
# Out:
# C:\Users\BoilingMachine\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2021 = pd.read_csv("year_2021_cut.csv")
df2020 = pd.read_csv("year_2020_cut.csv")

# %%
df2020
# Out:
#         Unnamed: 0                                               name  \
# 0                0                                     Тестировщик QA
# 1                1                                    PHP-разработчик
# 2                2                               Оператор саll-центра
# 3                3  Продавец - Консультант офиса продаж и обслужив...
# 4                4                            Технический консультант
# ...            ...                                                ...
# 489467      489467              Senior Data Scientist (Академгородок)
# 489468      489468                               Менеджер по продажам
# 489469      489469                             Ведущий программист 1С
# 489470      489470                            Marketing Product Owner
# 489471      489471                              Middle ABAP Developer
#
#                                               description  \
# 0       <p><strong>О Компании</strong></p> <p>Мы помог...
# ...

# %%
df2021
# Out:
#         Unnamed: 0                                               name  \
# 0                0                       PHP Веб-разработчик Bitrix24
# 1                1                                Инженер-программист
# 2                2  Ведущий специалист (Отдел технического обслужи...
# 3                3                                    Разработчик ETL
# 4                4         PHP разработчик / PHP Developer (удаленно)
# ...            ...                                                ...
# 229090      229090                               Аналитик CRM системы
# 229091      229091  Руководитель интернет-магазина (e-commerce, fa...
# 229092      229092                     Оператор технической поддержки
# 229093      229093                                        Инсталлятор
# 229094      229094  ИТ ДИРЕКТОР ( Логистический стартап федерально...
#
#                                               description  \
# 0       <p><strong>Факт </strong>- лидер рынка веб-инт...
# ...
